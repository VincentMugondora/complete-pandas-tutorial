# %% [markdown]
# ## Intro to Dataframes

# %%
import pandas as pd

df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])

print(df)
# Out:
# Running cells with 'venv (Python 3.13.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/DELL/Desktop/complete-pandas-tutorial/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
